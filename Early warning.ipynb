# %%
import pickle
with open('name_sex_dict.pkl', 'rb') as pickle_file:
    name_sex_dict = pickle.load(pickle_file)

# %%
import pandas as pd
excel_path_1 = 'Final_res.xlsx'
excel_path_2 = 'Police.xlsx'
res = pd.read_excel(excel_path_1, sheet_name='Sheet1')
p = pd.read_excel(excel_path_2, sheet_name='Sheet2')

# %%
res['Sex'] = res['Case'].map(name_sex_dict)

# %%
res['Mask_File_Path'] = aa['Mask_File_Path']
res['IMG_File_Path'] = aa['IMG_File_Path']

# %%
res = res[res['Channel'].isin(p['Channel'])].reset_index().drop(['index'],axis=1)
res
# Out:
#     Case Time  Channel     Mean_H     Pred_H     Mean_R     Pred_R  \
# 0    孔令华    a        1   4.410000   4.514158  15.843333  15.922121
# 1    孔令华    a        2   4.130000   4.362631  16.273333  16.138397
# 2    孔令华    a        3   4.250000   4.661199  15.870000  16.418090
# 3    孔令华    a        4   5.190000   4.962573  17.713333  17.360039
# 4    孔令华    a        5   5.813333   5.149423  18.140000  17.766602
# ..   ...  ...      ...        ...        ...        ...        ...
# 720   曹娇    m       19   5.966667   6.120857  32.483333  31.869890
# 721   曹娇    m       20   7.266667   7.156574  34.313333  33.786460
# 722   曹娇    m       21   8.653333   8.580939  35.970000  36.269990
# 723   曹娇    m       22  10.216667  10.752476  35.796667  36.936226
# 724   曹娇    m       23   8.723333   8.974194  30.423333  32.203255
#
#          Mean_T     Pred_T Sex  \
# 0    194.333333  205.40076   M
# 1    210.666667  184.90773   M
# 2    227.000000  160.71365   M
# 3    197.000000  159.74281   M
# 4    240.000000  207.27783   M
# ..          ...        ...  ..
# 720  254.000000  260.83304   F
# 721  251.000000  258.96234   F
# 722  246.000000  258.21555   F
# 723  240.333333  268.32513   F
# 724  256.333333  285.58017   F
#
#                                         Mask_File_Path  \
# 0    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 1    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 2    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 3    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 4    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# ..                                                 ...
# 720  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 721  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 722  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 723  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 724  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
#
#                                          IMG_File_Path
# 0    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 1    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 2    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 3    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 4    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# ..                                                 ...
# 720  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 721  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 722  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 723  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 724  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
#
# [725 rows x 12 columns]

# %%
p
# Out:
#     Channel Sex    Hmin    Hmax     Rmin     Rmax
# 0         1   M   4.437   5.423  13.7880  16.8520
# 1         2   M   4.626   5.654  14.1930  17.3470
# 2         3   M   4.815   5.885  14.5980  17.8420
# 3         4   M   5.004   6.116  15.0030  18.3370
# 4         5   M   5.193   6.347  15.4080  18.8320
# 5         8   M   3.150   3.850  18.0900  22.1100
# 6        10   M   2.790   3.410  21.6000  26.4000
# 7        12   M   3.420   4.180  24.9300  30.4700
# 8        14   M   3.510   4.290  28.0800  34.3200
# 9        16   M   3.330   4.070  29.0700  35.5300
# 10       19   M   7.227   8.833  29.6235  36.2065
# 11       20   M   8.793  10.747  30.1770  36.8830
# 12       21   M  10.098  12.342  31.5090  38.5110
# 13       22   M  10.755  13.145  31.5990  38.6210
# 14       23   M   9.441  11.539  29.9340  36.5860
# 15        1   F   3.996   4.884  18.5490  22.6710
# 16        2   F   4.194   5.126  19.8000  24.2000
# 17        3   F   4.392   5.368  21.0510  25.7290
# 18        4   F   4.590   5.610  22.3020  27.2580
# 19        5   F   4.788   5.852  23.5530  28.7870
# 20        8   F   2.700   3.300  15.9300  19.4700
# 21       10   F   2.610   3.190  18.9900  23.2100
# 22       12   F   3.150   3.850  22.1400  27.0600
# 23       14   F   3.330   4.070  24.3900  29.8100
# 24       16   F   3.420   4.180  25.4700  31.1300
# 25       19   F   6.615   8.085  26.4195  32.2905
# 26       20   F   8.127   9.933  27.3690  33.4510
# 27       21   F   9.441  11.539  28.0080  34.2320
# 28       22   F  10.098  12.342  28.9890  35.4310
# 29       23   F   8.955  10.945  27.5040  33.6160

# %%
merged = res.merge(p, on=['Channel','Sex'], how='left')
merged
# Out:
#     Case Time  Channel     Mean_H     Pred_H     Mean_R     Pred_R  \
# 0    孔令华    a        1   4.410000   4.514158  15.843333  15.922121
# 1    孔令华    a        2   4.130000   4.362631  16.273333  16.138397
# 2    孔令华    a        3   4.250000   4.661199  15.870000  16.418090
# 3    孔令华    a        4   5.190000   4.962573  17.713333  17.360039
# 4    孔令华    a        5   5.813333   5.149423  18.140000  17.766602
# ..   ...  ...      ...        ...        ...        ...        ...
# 720   曹娇    m       19   5.966667   6.120857  32.483333  31.869890
# 721   曹娇    m       20   7.266667   7.156574  34.313333  33.786460
# 722   曹娇    m       21   8.653333   8.580939  35.970000  36.269990
# 723   曹娇    m       22  10.216667  10.752476  35.796667  36.936226
# 724   曹娇    m       23   8.723333   8.974194  30.423333  32.203255
#
#          Mean_T     Pred_T Sex  \
# 0    194.333333  205.40076   M
# 1    210.666667  184.90773   M
# 2    227.000000  160.71365   M
# 3    197.000000  159.74281   M
# 4    240.000000  207.27783   M
# ..          ...        ...  ..
# 720  254.000000  260.83304   F
# 721  251.000000  258.96234   F
# 722  246.000000  258.21555   F
# 723  240.333333  268.32513   F
# 724  256.333333  285.58017   F
#
#                                         Mask_File_Path  \
# 0    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 1    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 2    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 3    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 4    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# ..                                                 ...
# 720  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 721  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 722  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 723  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 724  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
#
#                                          IMG_File_Path    Hmin    Hmax  \
# 0    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   4.437   5.423
# 1    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   4.626   5.654
# 2    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   4.815   5.885
# 3    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   5.004   6.116
# 4    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   5.193   6.347
# ..                                                 ...     ...     ...
# 720  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   6.615   8.085
# 721  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   8.127   9.933
# 722  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   9.441  11.539
# 723  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...  10.098  12.342
# 724  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   8.955  10.945
#
#         Rmin     Rmax
# 0    13.7880  16.8520
# 1    14.1930  17.3470
# 2    14.5980  17.8420
# 3    15.0030  18.3370
# 4    15.4080  18.8320
# ..       ...      ...
# 720  26.4195  32.2905
# 721  27.3690  33.4510
# 722  28.0080  34.2320
# 723  28.9890  35.4310
# 724  27.5040  33.6160
#
# [725 rows x 16 columns]

# %%
# 定义颜色转换函数
def color_change(val, min_val, max_val):
    color = 'red' if val < min_val or val > max_val else 'green'
    return f'color: {color}'

# 函数用于逐行处理DataFrame并应用样式
def apply_style(row):
    mean_h_style = color_change(row['Mean_H'], row['Hmin'], row['Hmax'])
    pred_h_style = color_change(row['Pred_H'], row['Hmin'], row['Hmax'])
    mean_r_style = color_change(row['Mean_R'], row['Rmin'], row['Rmax'])
    pred_r_style = color_change(row['Pred_R'], row['Rmin'], row['Rmax'])
    return [mean_h_style, pred_h_style,mean_r_style,pred_r_style]

# 使用Styler应用格式化
styled_df = merged[['Case','Time','Channel','Mean_H','Pred_H','Mean_R','Pred_R','Hmin','Hmax','Rmin','Rmax']].style.apply(
    lambda row: pd.Series(apply_style(row), index=['Mean_H', 'Pred_H','Mean_R','Pred_R']),
    axis=1
)

styled_df

# %%
from pandas.io.formats.style import Styler

# 保存到 Excel 文件
with pd.ExcelWriter('styled_dataframe.xlsx', engine='openpyxl') as writer:
    styled_df.to_excel(writer, sheet_name='Sheet1', engine='openpyxl')

# %%
import pandas as pd
from colorama import Fore, Style, init

# 初始化colorama
init(autoreset=True)

def check_and_mark(value, min_value, max_value):
    if value < min_value or value > max_value:
        return f'Warning'
    else:
        return f'Normal'

# 使用apply方法更新DataFrame中的Mean_H和Pred_H列
merged['Warn_M_H'] = merged.apply(lambda row: check_and_mark(row['Mean_H'], row['Hmin'], row['Hmax']), axis=1)
merged['Warn_P_H'] = merged.apply(lambda row: check_and_mark(row['Pred_H'], row['Hmin'], row['Hmax']), axis=1)
merged['Warn_M_R'] = merged.apply(lambda row: check_and_mark(row['Mean_R'], row['Rmin'], row['Rmax']), axis=1)
merged['Warn_P_R'] = merged.apply(lambda row: check_and_mark(row['Pred_R'], row['Rmin'], row['Rmax']), axis=1)
merged
# Out:
#     Case Time  Channel     Mean_H     Pred_H     Mean_R     Pred_R  \
# 0    孔令华    a        1   4.410000   4.514158  15.843333  15.922121
# 1    孔令华    a        2   4.130000   4.362631  16.273333  16.138397
# 2    孔令华    a        3   4.250000   4.661199  15.870000  16.418090
# 3    孔令华    a        4   5.190000   4.962573  17.713333  17.360039
# 4    孔令华    a        5   5.813333   5.149423  18.140000  17.766602
# ..   ...  ...      ...        ...        ...        ...        ...
# 720   曹娇    m       19   5.966667   6.120857  32.483333  31.869890
# 721   曹娇    m       20   7.266667   7.156574  34.313333  33.786460
# 722   曹娇    m       21   8.653333   8.580939  35.970000  36.269990
# 723   曹娇    m       22  10.216667  10.752476  35.796667  36.936226
# 724   曹娇    m       23   8.723333   8.974194  30.423333  32.203255
#
#          Mean_T     Pred_T Sex  \
# 0    194.333333  205.40076   M
# 1    210.666667  184.90773   M
# 2    227.000000  160.71365   M
# 3    197.000000  159.74281   M
# 4    240.000000  207.27783   M
# ..          ...        ...  ..
# 720  254.000000  260.83304   F
# 721  251.000000  258.96234   F
# 722  246.000000  258.21555   F
# 723  240.333333  268.32513   F
# 724  256.333333  285.58017   F
#
#                                         Mask_File_Path  \
# 0    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 1    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 2    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 3    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 4    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# ..                                                 ...
# 720  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 721  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 722  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 723  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 724  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
#
#                                          IMG_File_Path    Hmin    Hmax  \
# 0    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   4.437   5.423
# 1    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   4.626   5.654
# 2    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   4.815   5.885
# 3    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   5.004   6.116
# 4    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   5.193   6.347
# ..                                                 ...     ...     ...
# 720  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   6.615   8.085
# 721  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   8.127   9.933
# 722  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   9.441  11.539
# 723  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...  10.098  12.342
# 724  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   8.955  10.945
#
#         Rmin     Rmax Warn_M_H Warn_P_H Warn_M_R Warn_P_R
# 0    13.7880  16.8520  Warning   Normal   Normal   Normal
# 1    14.1930  17.3470  Warning  Warning   Normal   Normal
# 2    14.5980  17.8420  Warning  Warning   Normal   Normal
# 3    15.0030  18.3370   Normal  Warning   Normal   Normal
# 4    15.4080  18.8320   Normal  Warning   Normal   Normal
# ..       ...      ...      ...      ...      ...      ...
# 720  26.4195  32.2905  Warning  Warning  Warning   Normal
# 721  27.3690  33.4510  Warning  Warning  Warning  Warning
# 722  28.0080  34.2320  Warning  Warning  Warning  Warning
# 723  28.9890  35.4310   Normal   Normal  Warning  Warning
# 724  27.5040  33.6160  Warning   Normal   Normal   Normal
#
# [725 rows x 20 columns]

# %%
filtered_df = merged[(merged['Warn_P_H'] == 'Warning') | (merged['Warn_P_R'] == 'Warning')]
filtered_df
# Out:
#     Case Time  Channel     Mean_H     Pred_H     Mean_R     Pred_R  \
# 1    孔令华    a        2   4.130000   4.362631  16.273333  16.138397
# 2    孔令华    a        3   4.250000   4.661199  15.870000  16.418090
# 3    孔令华    a        4   5.190000   4.962573  17.713333  17.360039
# 4    孔令华    a        5   5.813333   5.149423  18.140000  17.766602
# 5    孔令华    a        8   2.303333   4.039949  22.146667  20.944372
# ..   ...  ...      ...        ...        ...        ...        ...
# 719   曹娇    m       16   5.393333   5.719643  28.656667  29.069248
# 720   曹娇    m       19   5.966667   6.120857  32.483333  31.869890
# 721   曹娇    m       20   7.266667   7.156574  34.313333  33.786460
# 722   曹娇    m       21   8.653333   8.580939  35.970000  36.269990
# 723   曹娇    m       22  10.216667  10.752476  35.796667  36.936226
#
#          Mean_T     Pred_T Sex  \
# 1    210.666667  184.90773   M
# 2    227.000000  160.71365   M
# 3    197.000000  159.74281   M
# 4    240.000000  207.27783   M
# 5    173.000000  191.49553   M
# ..          ...        ...  ..
# 719  269.666667  293.14804   F
# 720  254.000000  260.83304   F
# 721  251.000000  258.96234   F
# 722  246.000000  258.21555   F
# 723  240.333333  268.32513   F
#
#                                         Mask_File_Path  \
# 1    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 2    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 3    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 4    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# 5    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...
# ..                                                 ...
# 719  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 720  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 721  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 722  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
# 723  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...
#
#                                          IMG_File_Path    Hmin    Hmax  \
# 1    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   4.626   5.654
# 2    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   4.815   5.885
# 3    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   5.004   6.116
# 4    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   5.193   6.347
# 5    Stage_1_infer/Case_┐╫┴ε╗¬/┐╫┴ε╗¬_2018110600027...   3.150   3.850
# ..                                                 ...     ...     ...
# 719  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   3.420   4.180
# 720  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   6.615   8.085
# 721  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   8.127   9.933
# 722  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...   9.441  11.539
# 723  Stage_1_infer/Case_▓▄╜┐/▓▄╜┐_20190125000266_10...  10.098  12.342
#
#         Rmin     Rmax Warn_M_H Warn_P_H Warn_M_R Warn_P_R
# 1    14.1930  17.3470  Warning  Warning   Normal   Normal
# 2    14.5980  17.8420  Warning  Warning   Normal   Normal
# 3    15.0030  18.3370   Normal  Warning   Normal   Normal
# 4    15.4080  18.8320   Normal  Warning   Normal   Normal
# 5    18.0900  22.1100  Warning  Warning  Warning   Normal
# ..       ...      ...      ...      ...      ...      ...
# 719  25.4700  31.1300  Warning  Warning   Normal   Normal
# 720  26.4195  32.2905  Warning  Warning  Warning   Normal
# 721  27.3690  33.4510  Warning  Warning  Warning  Warning
# 722  28.0080  34.2320  Warning  Warning  Warning  Warning
# 723  28.9890  35.4310   Normal   Normal  Warning  Warning
#
# [554 rows x 20 columns]

# %%
Sex_full = {'F':'Female','M':'Male'}
Time_full = {'a':'Afternoon','m':'Morning'}
Channel_full = {1:'C2-3',2:'C3-4',3:'C4-5',4:'C5-6',5:'C6-7',6:'C7-T1',7:'T1-2',8:'T2-3',9:'T3-4',10:'T4-5',11:'T5-6',12:'T6-7',13:'T7-8',14:'T8-9',15:'T9-10',16:'T10-11',17:'T11-12',18:'T12-L1',19:'L1-2',20:'L2-3',21:'L3-4',22:'L4-5',23:'L5-S1'}

# %%
filtered_df['Mean_H'] = filtered_df['Mean_H'].round(2)
filtered_df['Pred_H'] = filtered_df['Pred_H'].round(2)
filtered_df['Mean_R'] = filtered_df['Mean_R'].round(2)
filtered_df['Pred_R'] = filtered_df['Pred_R'].round(2)
filtered_df['Sex'] = filtered_df['Sex'].map(Sex_full)
filtered_df['Time'] = filtered_df['Time'].map(Time_full)
filtered_df['Channel'] = filtered_df['Channel'].map(Channel_full)
# Out:
# /tmp/ipykernel_568/3365563780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Mean_H'] = filtered_df['Mean_H'].round(2)
# /tmp/ipykernel_568/3365563780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Pred_H'] = filtered_df['Pred_H'].round(2)
# /tmp/ipykernel_568/3365563780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Mean_R'] = filtered_df['Mean_R'].round(2)
# /tmp/ipykernel_568/3365563780.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Pred_R'] = filtered_df['Pred_R'].round(2)
# /tmp/ipykernel_568/3365563780.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Sex'] = filtered_df['Sex'].map(Sex_full)
# /tmp/ipykernel_568/3365563780.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Time'] = filtered_df['Time'].map(Time_full)
# /tmp/ipykernel_568/3365563780.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Channel'] = filtered_df['Channel'].map(Channel_full)

# %%
import cv2
import pandas as pd
import numpy as np
import os

output_folder = 'Warning_images'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    
def sharpen_image(image):
    # 定义锐化核
    kernel = np.array([
        [-1, -1, -1],
        [-1, 9, -1],
        [-1, -1, -1]
    ])
    # 使用卷积核进行锐化
    sharpened_image = cv2.filter2D(image, -1, kernel)
    return sharpened_image
    
def create_composite_image(row):
    # 读取图片
    composite_image = cv2.imread(row['IMG_File_Path'])

    # 调整图片的大小
    new_size = (512, 512)
    composite_image = cv2.resize(composite_image, new_size)
    composite_image = sharpen_image(composite_image)
    
    # 设置字体及字号
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 0.8
    thickness = 2

    # 根据 Warn_M_H 列决定颜色
    if row['Warn_M_H'] == 'Warning':
        Warn_M_H_text_color = (0, 0, 255)  # 红色
    else:
        Warn_M_H_text_color = (0, 255, 0)  # 绿色

    if row['Warn_P_H'] == 'Warning':
        Warn_P_H_text_color = (0, 0, 255)  # 红色
    else:
        Warn_P_H_text_color = (0, 255, 0)  # 绿色
        
    if row['Warn_M_R'] == 'Warning':
        Warn_M_R_text_color = (0, 0, 255)  # 红色
    else:
        Warn_M_R_text_color = (0, 255, 0)  # 绿色
        
    if row['Warn_P_R'] == 'Warning':
        Warn_P_R_text_color = (0, 0, 255)  # 红色
    else:
        Warn_P_R_text_color = (0, 255, 0)  # 绿色
    
    # 在左上角标注 Mean_H, Pred_H, Mean_R, Pred_R 四列对应值
    cv2.putText(composite_image, f"Mean H: {row['Mean_H']}", (10, 20), font, font_scale, Warn_M_H_text_color, thickness, cv2.LINE_AA)
    cv2.putText(composite_image, f"Pred H: {row['Pred_H']}", (10, 45), font, font_scale, Warn_P_H_text_color, thickness, cv2.LINE_AA)
    cv2.putText(composite_image, f"Mean R: {row['Mean_R']}", (10, 70), font, font_scale, Warn_M_R_text_color, thickness, cv2.LINE_AA)
    cv2.putText(composite_image, f"Pred R: {row['Pred_R']}", (10, 95), font, font_scale, Warn_P_R_text_color, thickness, cv2.LINE_AA)

    # 在左下角标注 Sex, Time, Channel
    cv2.putText(composite_image, f"Sex: {row['Sex']}", (10, composite_image.shape[0] - 70), font, font_scale, (255, 255, 255), thickness, cv2.LINE_AA)
    cv2.putText(composite_image, f"Time: {row['Time']}", (10, composite_image.shape[0] - 45), font, font_scale, (255, 255, 255), thickness, cv2.LINE_AA)
    cv2.putText(composite_image, f"Channel: {row['Channel']}", (10, composite_image.shape[0] - 20), font, font_scale, (255, 255, 255), thickness, cv2.LINE_AA)

    # 保存图片
    composite_image_path = f"{output_folder}/composite_image_{row.name}.png"
    cv2.imwrite(composite_image_path, composite_image)
    print(f"Saved {composite_image_path}")

for index, row in filtered_df.iterrows():
    create_composite_image(row)
    #break  # 如果只需要处理一行，可以保留这个break，如果需要处理所有行，请移除这个break
